# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import xlrd, xlwt

# %%
neng_data = pd.ExcelFile('countries.xlsx')
f1 = lambda x:(x.max()-x)/(x.max()-x.min())
f2 = lambda x:(x-x.min())/(x.max()-x.min())

# %%
def read_sheet(data,sheetname):
    table_data = data.parse(sheetname)
    table_data = table_data.T
    table_data_ = table_data[1:]
    tabel_data_ = table_data_.dropna(axis=1,how='all')
    table_data_mean = table_data_.mean()
    #print(table_data_mean)
    t0 = table_data.fillna(dict(table_data_mean))
    t0 = t0.ix[1:].dropna(axis=1,how='all')
    #print(t0.ix[:,19])
    t1 = t0.ix[:,0:14].apply(f1)
    #print(t1)
    t2 = t0.ix[:,15:25].apply(f2)
    #print(t2)
    t3 = t1.add(t2,fill_value=0)
    t3 = t3.T
    t4 = t3.reindex(index=range(26),fill_value=0)
    INDEX = table_data.ix[0]
    t4.index = INDEX
    #print(t4)
    t4.to_excel(sheetname + '.xlsx',sheet_name=sheetname)

# %%
names= neng_data.sheet_names
names[11]
# Out:
# 'SSD'

# %%
read_sheet(neng_data,names[38])
# Out:
# /home/onexiaomin/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:9: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /home/onexiaomin/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:11: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /home/onexiaomin/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:18: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
def read_sheet_two(data,sheetname):
    table_data = data.parse(sheetname)
    table_data = table_data.T
    table_data_ = table_data[1:]
    tabel_data_ = table_data_.dropna(axis=1,how='all')
    table_data_mean = table_data_.mean()
    t0 = table_data_.fillna(dict(table_data_mean))
    t0 = t0.dropna(axis = 1,how ='all')
    table_data_std = t0.std()
    table_data_mean= t0.mean()
    #print(table_data_mean)
    #print(table_data_std)
    tabel_data_A = table_data_std/table_data_mean
    #print(tabel_data_A)
    tabel_data_A_sum = sum(tabel_data_A)
    table_data_w = tabel_data_A/tabel_data_A_sum
    
    table_data_w = table_data_w.reindex(index=range(26),fill_value=0)
    #print(table_data_w)
    INDEX = table_data.ix[0]
    table_data_w.index=INDEX
    #print(table_data_w)
    table_data_w.to_excel(sheetname + '.xlsx',sheet_name=sheetname)

# %%
for i in range(54): 
    read_sheet_two(neng_data,names[i])
# Out:
# /home/onexiaomin/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:19: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
def read_sheet_three(data,sheetname):
    table_data = data.parse(sheetname)
    table_data = table_data.T
    table_data_ = table_data[1:]
    tabel_data_ = table_data_.dropna(axis=1,how='all')
    table_data_mean = table_data_.mean()
    #print(table_data_mean)
    t0 = table_data.fillna(dict(table_data_mean))
    t0 = t0.ix[1:].dropna(axis=1,how='all')
    
    table_data_std = t0.std()
    table_data_mean= t0.mean()
    tabel_data_A = table_data_std/table_data_mean
    tabel_data_A_sum = sum(tabel_data_A)
    table_data_w = tabel_data_A/tabel_data_A_sum
    
    t1 = t0.ix[:,0:14].apply(f1)
    t2 = t0.ix[:,15:25].apply(f2)
    t3 = t1.add(t2,fill_value=0)
    
    #print(t3)
    #print(table_data_w)
    t4 = t3*table_data_w
    #print(t4)
    t4 = t4.T
    t4 = t4.reindex(index=range(26),fill_value=0)
    INDEX = table_data.ix[0]
    t4.index = INDEX
    #print(t4)
    t4.to_excel(sheetname + '.xlsx',sheet_name=sheetname)

# %%
read_sheet_three(neng_data,names[11])
# Out:
#                                       1994      1995      1996      1997  \
# 南苏丹指标层
# 人均 GDP增长（年增长率）                   -0.421141 -0.421141 -0.421141 -0.421141
# 城镇人口（占总人口比例）                      0.062156  0.059807  0.057458  0.055071
# 城镇人口增长率（年增长率）                     0.342404  0.251014  0.144045  0.056116
# 农村人口增长（年增长率）                      0.454354  0.333198  0.190808  0.074792
# 人口增长（年度百分比）                       0.430284  0.315558  0.180827  0.070880
# 65岁和65岁以上的人口（占总人口的百分比）            0.069056  0.071408  0.067573  0.063775
# 总生育率(女性人均生育数）                     0.000000  0.002760  0.005756  0.009221
# 出生时的预期寿命，总体（岁）                    0.062763  0.059025  0.055602  0.052453
# 死亡率，婴幼儿（每千例活产儿）                   0.000000  0.015425  0.031621  0.048588
# 按来源国家或地区划分的难民人数                   0.371629  0.371629  0.371629  0.371629
# 进口价值指数（2000 年 = 100）              0.000000  0.000000  0.000000  0.000000
# 出口价值指数（2000 年 = 100）              0.000000  0.000000  0.000000  0.000000
# 人口密度（每公里土地面积人数）                   0.000000  0.000000  0.000000  0.000000
# 其他温室气体排放量，HFC、PFC和SF6（千公吨二氧化碳当量）  0.000000  0.000000  0.000000  0.000000
# 二氧化碳排放量（人均公吨数）                    0.003387  0.003387  0.003387  0.003387
# 城市改善的水源（获得改善水源的城市人口所占百分比）         0.000000  0.000000  0.000000  0.000000
# 农村改善的水源（获得改善水源的农村人口所占百分比）         0.000000  0.000000  0.000000  0.000000
# 森林面积（占土地面积的百分比）                   0.000000  0.000000  0.000000  0.000000
# 耕地（人均公顷数）                         0.000000  0.000000  0.000000  0.000000
# 调整后的储蓄： 教育支出（占 GNI 的百分比）          0.000000  0.000000  0.000000  0.000000
# 经过改善的卫生设施（获得经过改善的设施的人口所占百分比）      0.002307  0.002307  0.002307  0.002307
# 畜牧业生产指数（2004 年 - 2001 年 = 100）    0.000000  0.000000  0.000000  0.000000
# 食品生产指数（2004 年 - 2001 年 = 100）     0.000000  0.000000  0.000000  0.000000
# 作物生产指数（2004 年-2006 年= 100）        0.000000  0.000000  0.000000  0.000000
# 劳动力，总数                            0.000000  0.000000  0.000000  0.000000
# 科技期刊文章                            0.000000  0.000000  0.000000  0.000000
#
#                                       1998      1999      2000      2001  \
# 南苏丹指标层
# 人均 GDP增长（年增长率）                   -0.421141 -0.421141 -0.421141 -0.421141
# 城镇人口（占总人口比例）                      0.052684  0.050278  0.047853  0.045428
# 城镇人口增长率（年增长率）                     0.005348  0.000000  0.022624  0.051320
# 农村人口增长（年增长率）                      0.006978  0.000000  0.030133  0.067774
# 人口增长（年度百分比）                       0.006704  0.000000  0.028406  0.064001
# 65岁和65岁以上的人口（占总人口的百分比）            0.060216  0.056600  0.052544  0.048964
# 总生育率(女性人均生育数）                     0.013156  0.017502  0.022201  0.027134
# 出生时的预期寿命，总体（岁）                    0.049525  0.046787  0.044211  0.041759
# 死亡率，婴幼儿（每千例活产儿）                   0.066327  0.084837  0.104118  0.123399
# 按来源国家或地区划分的难民人数                   0.371629  0.371629  0.371629  0.371629
# 进口价值指数（2000 年 = 100）              0.000000  0.000000  0.000000  0.000000
# 出口价值指数（2000 年 = 100）              0.000000  0.000000  0.000000  0.000000
# 人口密度（每公里土地面积人数）                   0.000000  0.000000  0.000000  0.000000
# 其他温室气体排放量，HFC、PFC和SF6（千公吨二氧化碳当量）  0.000000  0.000000  0.000000  0.000000
# 二氧化碳排放量（人均公吨数）                    0.003387  0.003387  0.003387  0.003387
# 城市改善的水源（获得改善水源的城市人口所占百分比）         0.000000  0.000000  0.000000  0.000000
# 农村改善的水源（获得改善水源的农村人口所占百分比）         0.000000  0.000000  0.000000  0.000000
# 森林面积（占土地面积的百分比）                   0.000000  0.000000  0.000000  0.000000
# 耕地（人均公顷数）                         0.000000  0.000000  0.000000  0.000000
# 调整后的储蓄： 教育支出（占 GNI 的百分比）          0.000000  0.000000  0.000000  0.000000
# 经过改善的卫生设施（获得经过改善的设施的人口所占百分比）      0.002307  0.002307  0.002307  0.002307
# 畜牧业生产指数（2004 年 - 2001 年 = 100）    0.000000  0.000000  0.000000  0.000000
# 食品生产指数（2004 年 - 2001 年 = 100）     0.000000  0.000000  0.000000  0.000000
# 作物生产指数（2004 年-2006 年= 100）        0.000000  0.000000  0.000000  0.000000
# 劳动力，总数                            0.000000  0.000000  0.000000  0.000000
# 科技期刊文章                            0.000000  0.000000  0.000000  0.000000
#
#                                       2002      2003    ...         2007  \
# 南苏丹指标层                                                  ...
# 人均 GDP增长（年增长率）                   -0.421141 -0.421141    ...    -0.421141
# 城镇人口（占总人口比例）                      0.042985  0.040522    ...     0.030500
# 城镇人口增长率（年增长率）                     0.068828  0.075229    ...     0.023997
# 农村人口增长（年增长率）                      0.091123  0.099720    ...     0.031624
# 人口增长（年度百分比）                       0.085988  0.094018    ...     0.029258
# 65岁和65岁以上的人口（占总人口的百分比）            0.045247  0.041257    ...     0.025607
# 总生育率(女性人均生育数）                     0.032126  0.037118    ...     0.056558
# 出生时的预期寿命，总体（岁）                    0.039379  0.037002    ...     0.026390
# 死亡率，婴幼儿（每千例活产儿）                   0.141523  0.159647    ...     0.222117
# 按来源国家或地区划分的难民人数                   0.371629  0.371629    ...     0.371629
# 进口价值指数（2000 年 = 100）              0.000000  0.000000    ...     0.000000
# 出口价值指数（2000 年 = 100）              0.000000  0.000000    ...     0.000000
# 人口密度（每公里土地面积人数）                   0.000000  0.000000    ...     0.000000
# 其他温室气体排放量，HFC、PFC和SF6（千公吨二氧化碳当量）  0.000000  0.000000    ...     0.000000
# 二氧化碳排放量（人均公吨数）                    0.003387  0.003387    ...     0.003387
# 城市改善的水源（获得改善水源的城市人口所占百分比）         0.000000  0.000000    ...     0.000000
# 农村改善的水源（获得改善水源的农村人口所占百分比）         0.000000  0.000000    ...     0.000000
# 森林面积（占土地面积的百分比）                   0.000000  0.000000    ...     0.000000
# 耕地（人均公顷数）                         0.000000  0.000000    ...     0.000000
# 调整后的储蓄： 教育支出（占 GNI 的百分比）          0.000000  0.000000    ...     0.000000
# 经过改善的卫生设施（获得经过改善的设施的人口所占百分比）      0.002307  0.002307    ...     0.002307
# 畜牧业生产指数（2004 年 - 2001 年 = 100）    0.000000  0.000000    ...     0.000000
# 食品生产指数（2004 年 - 2001 年 = 100）     0.000000  0.000000    ...     0.000000
# 作物生产指数（2004 年-2006 年= 100）        0.000000  0.000000    ...     0.000000
# 劳动力，总数                            0.000000  0.000000    ...     0.000000
# 科技期刊文章                            0.000000  0.000000    ...     0.000000
#
#                                       2008      2009      2010      2011  \
# 南苏丹指标层
# 人均 GDP增长（年增长率）                   -0.421141 -0.218177 -0.200406 -0.432909
# 城镇人口（占总人口比例）                      0.027943  0.025215  0.022260  0.019096
# 城镇人口增长率（年增长率）                     0.023774  0.031534  0.044512  0.058500
# 农村人口增长（年增长率）                      0.031950  0.046516  0.069490  0.093164
# 人口增长（年度百分比）                       0.029374  0.042350  0.063010  0.084417
# 65岁和65岁以上的人口（占总人口的百分比）            0.021965  0.017808  0.012901  0.009372
# 总生育率(女性人均生育数）                     0.061609  0.066719  0.071946  0.077232
# 出生时的预期寿命，总体（岁）                    0.023297  0.020043  0.016668  0.013229
# 死亡率，婴幼儿（每千例活产儿）                   0.234457  0.245255  0.255281  0.264150
# 按来源国家或地区划分的难民人数                   0.371629  0.371629  0.371629  0.573382
# 进口价值指数（2000 年 = 100）              0.000000  0.000000  0.000000  0.000000
# 出口价值指数（2000 年 = 100）              0.000000  0.000000  0.000000  0.000000
# 人口密度（每公里土地面积人数）                   0.000000  0.000000  0.000000  0.000000
# 其他温室气体排放量，HFC、PFC和SF6（千公吨二氧化碳当量）  0.000000  0.000000  0.000000  0.000000
# 二氧化碳排放量（人均公吨数）                    0.003387  0.003387  0.003387  0.003387
# 城市改善的水源（获得改善水源的城市人口所占百分比）         0.000000  0.000000  0.000000  0.000000
# 农村改善的水源（获得改善水源的农村人口所占百分比）         0.000000  0.000000  0.000000  0.000000
# 森林面积（占土地面积的百分比）                   0.000000  0.000000  0.000000  0.000000
# 耕地（人均公顷数）                         0.000000  0.000000  0.000000  0.000000
# 调整后的储蓄： 教育支出（占 GNI 的百分比）          0.000000  0.000000  0.000000  0.000000
# 经过改善的卫生设施（获得经过改善的设施的人口所占百分比）      0.002307  0.002307  0.002307  0.000000
# 畜牧业生产指数（2004 年 - 2001 年 = 100）    0.000000  0.000000  0.000000  0.000000
# 食品生产指数（2004 年 - 2001 年 = 100）     0.000000  0.000000  0.000000  0.000000
# 作物生产指数（2004 年-2006 年= 100）        0.000000  0.000000  0.000000  0.000000
# 劳动力，总数                            0.000000  0.000000  0.000000  0.000000
# 科技期刊文章                            0.000000  0.000000  0.000000  0.000000
#
#                                       2012      2013      2014      2015  \
# 南苏丹指标层
# 人均 GDP增长（年增长率）                   -1.410900 -0.000000 -0.228260 -0.457334
# 城镇人口（占总人口比例）                      0.015724  0.012124  0.008317  0.004281
# 城镇人口增长率（年增长率）                     0.069677  0.078387  0.084387  0.087907
# 农村人口增长（年增长率）                      0.112998  0.129948  0.142675  0.152482
# 人口增长（年度百分比）                       0.102184  0.117128  0.128157  0.136328
# 65岁和65岁以上的人口（占总人口的百分比）            0.005774  0.002603  0.000611  0.000000
# 总生育率(女性人均生育数）                     0.082459  0.087627  0.092737  0.097671
# 出生时的预期寿命，总体（岁）                    0.009796  0.006430  0.003159  0.000000
# 死亡率，婴幼儿（每千例活产儿）                   0.273019  0.281117  0.289215  0.295771
# 按来源国家或地区划分的难民人数                   0.538656  0.527697  0.327449  0.262591
# 进口价值指数（2000 年 = 100）              0.000000  0.000000  0.000000  0.000000
# 出口价值指数（2000 年 = 100）              0.000000  0.000000  0.000000  0.000000
# 人口密度（每公里土地面积人数）                   0.000000  0.000000  0.000000  0.000000
# 其他温室气体排放量，HFC、PFC和SF6（千公吨二氧化碳当量）  0.000000  0.000000  0.000000  0.000000
# 二氧化碳排放量（人均公吨数）                    0.009922  0.000239  0.000000  0.003387
# 城市改善的水源（获得改善水源的城市人口所占百分比）         0.000000  0.000000  0.000000  0.000000
# 农村改善的水源（获得改善水源的农村人口所占百分比）         0.000000  0.000000  0.000000  0.000000
# 森林面积（占土地面积的百分比）                   0.000000  0.000000  0.000000  0.000000
# 耕地（人均公顷数）                         0.000000  0.000000  0.000000  0.000000
# 调整后的储蓄： 教育支出（占 GNI 的百分比）          0.000000  0.000000  0.000000  0.000000
# 经过改善的卫生设施（获得经过改善的设施的人口所占百分比）      0.000000  0.003845  0.003845  0.003845
# 畜牧业生产指数（2004 年 - 2001 年 = 100）    0.000000  0.000000  0.000000  0.000000
# 食品生产指数（2004 年 - 2001 年 = 100）     0.000000  0.000000  0.000000  0.000000
# 作物生产指数（2004 年-2006 年= 100）        0.000000  0.000000  0.000000  0.000000
# 劳动力，总数                            0.000000  0.000000  0.000000  0.000000
# 科技期刊文章                            0.000000  0.000000  0.000000  0.000000
#
#                                       2016
# 南苏丹指标层
# 人均 GDP增长（年增长率）                   -0.421141
# 城镇人口（占总人口比例）                      0.000000
# 城镇人口增长率（年增长率）                     0.090940
# 农村人口增长（年增长率）                      0.162004
# 人口增长（年度百分比）                       0.144131
# 65岁和65岁以上的人口（占总人口的百分比）            0.000937
# 总生育率(女性人均生育数）                     0.045552
# 出生时的预期寿命，总体（岁）                    0.031974
# 死亡率，婴幼儿（每千例活产儿）                   0.302712
# 按来源国家或地区划分的难民人数                   0.000000
# 进口价值指数（2000 年 = 100）              0.000000
# 出口价值指数（2000 年 = 100）              0.000000
# 人口密度（每公里土地面积人数）                   0.000000
# 其他温室气体排放量，HFC、PFC和SF6（千公吨二氧化碳当量）  0.000000
# 二氧化碳排放量（人均公吨数）                    0.003387
# 城市改善的水源（获得改善水源的城市人口所占百分比）         0.000000
# 农村改善的水源（获得改善水源的农村人口所占百分比）         0.000000
# 森林面积（占土地面积的百分比）                   0.000000
# 耕地（人均公顷数）                         0.000000
# 调整后的储蓄： 教育支出（占 GNI 的百分比）          0.000000
# 经过改善的卫生设施（获得经过改善的设施的人口所占百分比）      0.002307
# 畜牧业生产指数（2004 年 - 2001 年 = 100）    0.000000
# 食品生产指数（2004 年 - 2001 年 = 100）     0.000000
# 作物生产指数（2004 年-2006 年= 100）        0.000000
# 劳动力，总数                            0.000000
# 科技期刊文章                            0.000000
#
# [26 rows x 23 columns]
# /home/onexiaomin/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:9: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /home/onexiaomin/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:17: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /home/onexiaomin/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:27: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
